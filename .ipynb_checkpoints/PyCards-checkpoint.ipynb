# %%
import random
SUITS = '♠,♥,♦,♣,R'.split(',')
RANKS = '2,3,4,5,6,7,8,9,0,J,Q,K,A'.split(',')
#print(SUITS)
#print(RANKS)

class Player:
    def __init__(self, name):      
        self.name = name
        self.hand=[];
        self.tricks=[];
   
    def add_card_to_hand(self, card):
        self.hand.append(card)
    
    
    def name(self):
        return self.name
    
    def __str__(self):
         return self.name + '\nHand:' +  str(self.hand) + '\nTricks:' + str(self.tricks) + '\n'
    def __repr__(self): 
         return self.__str__()
        
class Card:
    # Initializer / Instance Attributes
    def __init__(self, number):      
        self.suit = SUITS[int(number/13)%4] #%4 if there more then one deck
        self.rank = RANKS[number%13]
        #print (str(number) + self.suit + self.rank)
    
    def name(self):
        return self.suit + self.rank
    
    def points(self): # @TODO: figure out a generic way to provide value method.
        if self.rank == '9' or self.rank == 'A' :
            return 20
        if self.rank ==  '0':
            return 10
        if self.rank == 'Q':
            return 2
        if self.rank == 'K':
            return 3
        if self.rank == 'J' and self.suit == '♠':
            return 40
        return 0
        
    
    def __str__(self):
         return self.suit + self.rank
    def __repr__(self): 
          return self.suit + self.rank
    def __cmp__(self, other):
        return self.number - other.number

class Table:
    def __init__(self, number_of_decks):
        self.number_of_decks = number_of_decks
        self.players = []
        self.deck = []
        self.initialize_decks()
        
    def initialize_decks(self):
        total_points = 0
        for i in range(52*self.number_of_decks):
            card = Card(i)
            self.deck.append(card)
            total_points += card.points()
#            print('{} \t{}'.format(card, card.points()))
        print('Total\t' + str(total_points))
    
    def shuffle_decks(self):
        for i in range(52*self.number_of_decks):
            random1 = random.randint(0, 52*self.number_of_decks);
            random2 = random.randint(0, 52*self.number_of_decks1);
            #print(random1, random2)
            tempcard = self.deck[random1]
            self.deck[random1] = self.deck[random2]
            self.deck[random2] = tempcard
      
    def add_player(self, player):
        self.players.append(player)

    def deal_cards(number):
        for i in range(number):
            for player in self.players:
                player.add_card_to_hand(deck.pop())

# %%
#deck
    






    
def initialize_table():
    table = Table(2) # new table with 2 decks
    #table.initialize_decks()

    #add players
    names = 'Harit,Yash,Anand,Jatin,Bhaven'.split(',')
    for name in names:
        table.add_player(Player(name))

    table.shuffle_decks()
    table.deal_cards_to_players(10)
    #print(players)
    return 

initialize_table()
# Out:
# Total	520
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8fe44a69db79> in <module>
#      22     return
#      23
# ---> 24 initialize_table()
#
# <ipython-input-46-8fe44a69db79> in initialize_table()
#       9
#      10 def initialize_table():
# ---> 11     table = Table(2) # new table with 2 decks
#      12     #table.initialize_decks()
#      13
#
# <ipython-input-45-ec3687b8c795> in __init__(self, number_of_decks)
#      59         self.players = []
#      60         self.deck = []
# ---> 61         self.initialize_decks()
#      62
#      63     def initialize_decks(self):
#
# <ipython-input-45-ec3687b8c795> in initialize_decks(self)
#      69 #            print('{} \t{}'.format(card, card.points()))
#      70         print('Total\t' + str(total_points))
# ---> 71         return deck
#      72
#      73     def shuffle_decks(self):
#
# NameError: name 'deck' is not defined

# %%
def play_game(players):
    # bidding process
    # decide the trump 
    # declare partner cards
    # Play tricks
        # start with the bid_winner
        # Find the trick winner
        # play next trick
    #decide score
    #count points.
